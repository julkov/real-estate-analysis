# %%
# %load_ext autoreload

# %%
# %autoreload 2
from crawler_analysis import *

# %%
df = read_data()

# %%
show_city_distribution(df)

# %% [markdown]
# ### Rozkład ofert w miejscowościach
# bubabiba

# %%
df.dtypes
# Out:
# link                         str
# city                         str
# street                       str
# price                    float64
# type                         str
# rooms                    float64
# surface                  float64
# furnished                    str
# description                  str
# description_eng              str
# near_school                int64
# near_hospital              int64
# near_public_transport      int64
# near_services              int64
# photos                    object
# dtype: object

# %%
show_distribution(df, "price", 3)

# %% [markdown]
# ### Rozkład cen za wynajem ofert

# %%
show_distribution(df, "surface", 50)

# %% [markdown]
# Rozkład powierzchni lokum dostępnych na stronie

# %%
show_distribution(df, "rooms", 4)

# %% [markdown]
# Rozkład liczby pokoi w ofertach

# %%
show_house_type_distribution(df)

# %% [markdown]
# Liczba lokum dostępnych w danym rodzaju

# %%
show_if_furnished(df)

# %% [markdown]
# Liczba ofert lokum umeblowanych i nieumeblowanych

# %%
box_price = df["price"].plot(kind="box", title="house price", figsize=(6,8), layout=(4, 4), ylim=(1, 6000))
plt.show()

# %% [markdown]
# Wykres skrzynkowy ofert o danej cenie

# %%
box_surface = df["surface"].plot(kind="box", title="house area", figsize=(6,8), layout=(4, 4), ylim=(1, 600))
plt.show()

# %% [markdown]
# Wykres szkrzynkowy ofert o danej powierzchni

# %%
df.describe().round(4)
# Out:
#            price      rooms    surface  near_school  near_hospital  \
# count  2251.0000  2251.0000  2251.0000    2251.0000      2251.0000
# mean   1542.2661     2.5686    74.6499       0.1755         0.0195
# std     881.0897     1.2568    89.6504       0.3805         0.1385
# min       1.0000     1.0000     6.0000       0.0000         0.0000
# 25%     834.0000     2.0000    35.0000       0.0000         0.0000
# 50%    1413.0000     2.0000    67.0000       0.0000         0.0000
# 75%    2050.0000     3.0000    99.0000       0.0000         0.0000
# max    8895.0000     5.0000  3364.0000       1.0000         1.0000
#
#        near_public_transport  near_services
# count              2251.0000      2251.0000
# mean                  0.6144         0.3305
# std                   0.4868         0.4705
# min                   0.0000         0.0000
# 25%                   0.0000         0.0000
# 50%                   1.0000         0.0000
# 75%                   1.0000         1.0000
# max                   1.0000         1.0000

# %% [markdown]
# Podstawowe statystyki

# %%
df[["price", "rooms", "surface", "near_school", "near_hospital", "near_public_transport", "near_services"]].corr()
# Out:
#                           price     rooms   surface  near_school  \
# price                  1.000000  0.662882  0.371466     0.120826
# rooms                  0.662882  1.000000  0.467822     0.181607
# surface                0.371466  0.467822  1.000000     0.081482
# near_school            0.120826  0.181607  0.081482     1.000000
# near_hospital          0.021290  0.045918  0.027833     0.061409
# near_public_transport  0.101249  0.015672 -0.006536     0.115930
# near_services          0.171298  0.103669  0.062508    -0.001379
#
#                        near_hospital  near_public_transport  near_services
# price                       0.021290               0.101249       0.171298
# rooms                       0.045918               0.015672       0.103669
# surface                     0.027833              -0.006536       0.062508
# near_school                 0.061409               0.115930      -0.001379
# near_hospital               1.000000               0.026152       0.084981
# near_public_transport       0.026152               1.000000       0.054116
# near_services               0.084981               0.054116       1.000000

# %% [markdown]
# Macierz korelacji

# %%
df.isnull().sum()
# Out:
# link                       0
# city                       0
# street                     0
# price                      0
# type                       0
# rooms                      0
# surface                    0
# furnished                230
# description                0
# description_eng            0
# near_school                0
# near_hospital              0
# near_public_transport      0
# near_services              0
# photos                    34
# dtype: int64

# %% [markdown]
# Braki danych

# %%
df.plot.scatter(x="price", y="rooms", xlim = (0,6000), ylim = (0,6))
plt.show()

# %% [markdown]
# Zależność ceny od liczby pokoi
