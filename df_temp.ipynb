# %%
import pandas as pd

df = pd.read_parquet("offers_df.parquet")
df[["link", "type", "furnished"]]
# Out:
#                                                    link         type  \
# 0     https://directwonen.nl/huurwoningen-huren/zaan...   APPARTMENT
# 1     https://directwonen.nl/huurwoningen-huren/eind...   APPARTMENT
# 2     https://directwonen.nl/huurwoningen-huren/amst...   APPARTMENT
# 3     https://directwonen.nl/huurwoningen-huren/rott...  STUDIO-ROOM
# 4     https://directwonen.nl/huurwoningen-huren/rott...  STUDIO-ROOM
# ...                                                 ...          ...
# 2246  https://directwonen.nl/huurwoningen-huren/utre...   APPARTMENT
# 2247  https://directwonen.nl/huurwoningen-huren/vlaa...  STUDIO-ROOM
# 2248  https://directwonen.nl/huurwoningen-huren/diem...        HOUSE
# 2249  https://directwonen.nl/huurwoningen-huren/vijf...  STUDIO-ROOM
# 2250  https://directwonen.nl/huurwoningen-huren/hill...   APPARTMENT
#
#          furnished
# 0              NaN
# 1              NaN
# 2              NaN
# 3     Gemeubileerd
# 4     Gemeubileerd
# ...
